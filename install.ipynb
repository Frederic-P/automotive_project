# %% [markdown]
# Since PIP cannot install the correct version of tensorflow and pytorch for use with ROCM. I made this notebook that installs all other tools you need after you installed ROCM, TensorFlow and Pytorch per AMD's instructions.
#
# This installar is compatible with ROCM 6.3 installations.

# %%
import sys
import subprocess

sys.path.append('utils')

# %%
installed_modules = subprocess.check_output(['pip', 'list']).decode('utf-8')

# %%
with open('requirements.txt', 'r', encoding='utf8') as f: 
    required_modules = f.readlines()

# %%
required_modules
# Out:
# ['absl-py==2.2.2\n',
#  'accelerate==1.6.0\n',
#  'aiohappyeyeballs==2.6.1\n',
#  'aiohttp==3.11.16\n',
#  'aiosignal==1.3.2\n',
#  'anyio==4.8.0\n',
#  'argon2-cffi==23.1.0\n',
#  'argon2-cffi-bindings==21.2.0\n',
#  'arrow==1.3.0\n',
#  'asttokens==3.0.0\n',
#  'astunparse==1.6.3\n',
#  'async-lru==2.0.4\n',
#  'attrs==25.1.0\n',
#  'babel==2.16.0\n',
#  'beautifulsoup4==4.12.3\n',
#  'bleach==6.2.0\n',
#  'blinker==1.9.0\n',
#  'certifi==2025.1.31\n',
#  'cffi==1.17.1\n',
#  'charset-normalizer==3.4.1\n',
#  'click==8.1.8\n',
#  'cloudscraper==1.2.71\n',
#  'comm==0.2.2\n',
#  'contourpy==1.3.1\n',
#  'cycler==0.12.1\n',
#  'debugpy==1.8.12\n',
#  'decorator==5.1.1\n',
#  'defusedxml==0.7.1\n',
#  'early-stopping-pytorch==1.0.10\n',
#  'executing==2.2.0\n',
#  'fastjsonschema==2.21.1\n',
#  'filelock==3.13.1\n',
#  'Flask==3.1.0\n',
#  'flatbuffers==25.2.10\n',
#  'fonttools==4.55.6\n',
#  'fqdn==1.5.1\n',
#  'frozenlist==1.5.0\n',
#  'fsspec==2024.2.0\n',
#  'gast==0.6.0\n',
# ...
