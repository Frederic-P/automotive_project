# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from sklearn.preprocessing import LabelEncoder
from PIL import Image
import pandas as pd
import os
import sys
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.metrics import confusion_matrix
import seaborn as sns

sys.path.append('../../utils')
from  configloader import Configloader
import implot
from database import Database
from file_io import path_handler
import cnn_helpers
from tqdm import tqdm

# %%
#important, this is needed to make it work on unsupported RX 6700XT card
cnn_helpers.system_override()
#os.system('export HSA_OVERRIDE_GFX_VERSION=10.3.0')
#os.system('export ROCM_PATH=/opt/rocm')
# Out:
# System override applied - check if GPU is detected

# %%
use_bbox = True    #run the model/training with bounding boxes when available?

# %%
# Load configuration
config = Configloader()
db = Database(config)
db.connect()
# Out:
# Connection established

# %%
# Image directory
basedir = config.get('settings', 'image_directory')

# %%
distinct_brands = db.execute_query('SELECT distinct(brand) FROM listings')

# %%
brands = pd.DataFrame(distinct_brands)

# %%
BRANDS = brands['brand']

# %%
def bbox_to_ints(df):
    df = df.copy()
    for col in ['yolobox_top_left_x', 'yolobox_top_left_y', 'yolobox_bottom_right_x', 'yolobox_bottom_right_y']:
        df[col] = df[col].astype(int)
    return df

# %%
# Query data
tags = db.execute_query("""SELECT
                            images.yolobox_top_left_x, 
                            images.yolobox_top_left_y, 
                            images.yolobox_bottom_right_x, 
                            images.yolobox_bottom_right_y, 
                            images.image_path, 
                            listings.brand
                        FROM images 
                        JOIN listings ON listings.id = images.listing_id
                        WHERE 
                            listings.countrycode = 'B' """)
labeled_data = pd.DataFrame(tags).fillna(-1)
labeled_data = cnn_helpers.cast_bbox_values(labeled_data)

# %%
labeled_data["image_path"] = labeled_data["image_path"].apply(lambda x: x.replace('\\', '/'))
labeled_data["abs_image_path"]= basedir + '/' + labeled_data["image_path"]

# %%
len(labeled_data)
# Out:
# 1354804

# %%
labeled_data.sample(5)
# Out:
#         yolobox_top_left_x  yolobox_top_left_y  yolobox_bottom_right_x  \
# 160185                 152                 126                     596
# 80298                   -1                  -1                      -1
# 150137                  -1                  -1                      -1
# 944114                  -1                  -1                      -1
# 60804                   -1                  -1                      -1
#
#         yolobox_bottom_right_y  \
# 160185                     450
# 80298                       -1
# 150137                      -1
# 944114                      -1
# 60804                       -1
#
#                                                image_path  brand  \
# 160185  skoda/Kamiq/00964738-2ba9-4e46-84bb-ac7c75fd5e...  skoda
# 80298   volvo/XC40/22c160e8-8ba1-4257-b5c7-cad98c6ae1e...  volvo
# 150137  skoda/Kodiaq/78ddc3d3-fe37-4568-8ee6-8a0a9c731...  skoda
# 944114  mini/3/5 Deurs/5c489d85-db98-4d40-9d94-768352a...   mini
# 60804   volvo/XC90/2df8ca49-f9d0-4457-830b-532bae6be02...  volvo
#
#                                            abs_image_path
# 160185  /home/frederic/Documents/automotive_image_data...
# 80298   /home/frederic/Documents/automotive_image_data...
# 150137  /home/frederic/Documents/automotive_image_data...
# 944114  /home/frederic/Documents/automotive_image_data...
# 60804   /home/frederic/Documents/automotive_image_data...

# %%
brand_encoder = LabelEncoder()
labeled_data['brand_numid'] = brand_encoder.fit_transform(labeled_data['brand'])  # Encode labels as numbers - pytorch is happy now s o me too :)
num_classes = len(brand_encoder.classes_)

# %%
brand_encoder.classes_
# Out:
# array(['alfa-romeo', 'alpine', 'audi', 'bmw', 'citroen', 'dacia', 'fiat',
#        'ford', 'honda', 'hyundai', 'jeep', 'kia', 'land-rover', 'lexus',
#        'lotus', 'mazda', 'mercedes-benz', 'mini', 'nissan', 'opel',
#        'peugeot', 'porsche', 'renault', 'seat', 'skoda', 'subaru',
#        'suzuki', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
smallerset = 0.05   #scale down labeled data to a fraction of the original: 
labeled_data = labeled_data.sample(frac=smallerset)

# %%
len(labeled_data)
# Out:
# 6774

# %%
# Custom Dataset for Online Loading
class ImageDataset(Dataset):
    def __init__(self, dataframe, use_bbox, transform=None):
        self.dataframe = dataframe
        self.transform = transform
        self.usebbox = use_bbox

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = self.dataframe.iloc[idx]['abs_image_path'] 
        label = self.dataframe.iloc[idx]['brand_numid']
        x1 = self.dataframe.iloc[idx]['yolobox_top_left_x']
        y1 = self.dataframe.iloc[idx]['yolobox_top_left_y']
        x2 = self.dataframe.iloc[idx]['yolobox_bottom_right_x']
        y2 = self.dataframe.iloc[idx]['yolobox_bottom_right_y']
        
        # Load image
        image = Image.open(img_path).convert('RGB')
        if self.usebbox and x1 != -1:
            image = image.crop((x1, y1, x2, y2))
        # Apply transformations if any
        if self.transform:
            image = self.transform(image)
        
        return image, label

# %%
# Transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resizing images to 224x224 for pretrained models
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Initialize Dataset and DataLoader
batch_size = 64
dataset = ImageDataset(labeled_data, use_bbox, transform=transform)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
# Define Model (Using a Pretrained Model)
model = models.resnet50(weights=None)
model.fc = nn.Linear(model.fc.in_features, len(labeled_data['brand'].unique()))  # Adjust output layer for classes
model = model.to('cuda' if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available():
    print('USING GPU ACCELERATION')
else:
    print('USING CPU')
# Out:
# USING GPU ACCELERATION

# %%
# Define Loss and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 5
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
for epoch in range(epochs):
    model.train()
    epoch_loss = 0.0
    
    for batch_idx, (images, labels) in enumerate(dataloader):
        images, labels = images.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
        print(f'Epoch {epoch+1}/{epochs}, Batch {batch_idx+1}/{len(dataloader)}, Loss: {loss.item():.4f}')

    print(f'Epoch {epoch+1} completed with average loss: {epoch_loss/len(dataloader):.4f}')
# Out:
# /home/frederic/Documents/automotive_project/lib/python3.12/site-packages/torch/nn/modules/linear.py:125: UserWarning: Attempting to use hipBLASLt on an unsupported architecture! Overriding blas backend to hipblas (Triggered internally at ../aten/src/ATen/Context.cpp:296.)
#   return F.linear(input, self.weight, self.bias)
# Epoch 1/5, Batch 1/106, Loss: 3.4193
# Epoch 1/5, Batch 2/106, Loss: 4.4871
# Epoch 1/5, Batch 3/106, Loss: 3.6134
# Epoch 1/5, Batch 4/106, Loss: 3.6789
# Epoch 1/5, Batch 5/106, Loss: 4.1056
# Epoch 1/5, Batch 6/106, Loss: 3.6420
# Epoch 1/5, Batch 7/106, Loss: 3.4165
# Epoch 1/5, Batch 8/106, Loss: 3.6987
# Epoch 1/5, Batch 9/106, Loss: 3.3973
# Epoch 1/5, Batch 10/106, Loss: 3.8128
# Epoch 1/5, Batch 11/106, Loss: 3.8112
# Epoch 1/5, Batch 12/106, Loss: 3.2650
# Epoch 1/5, Batch 13/106, Loss: 3.2736
# Epoch 1/5, Batch 14/106, Loss: 3.3529
# Epoch 1/5, Batch 15/106, Loss: 3.2591
# Epoch 1/5, Batch 16/106, Loss: 3.2023
# Epoch 1/5, Batch 17/106, Loss: 3.0345
# Epoch 1/5, Batch 18/106, Loss: 3.0868
# Epoch 1/5, Batch 19/106, Loss: 3.3657
# Epoch 1/5, Batch 20/106, Loss: 3.3151
# Epoch 1/5, Batch 21/106, Loss: 3.1517
# Epoch 1/5, Batch 22/106, Loss: 3.1107
# Epoch 1/5, Batch 23/106, Loss: 3.1925
# Epoch 1/5, Batch 24/106, Loss: 3.0326
# Epoch 1/5, Batch 25/106, Loss: 3.0133
# Epoch 1/5, Batch 26/106, Loss: 3.2521
# Epoch 1/5, Batch 27/106, Loss: 2.8991
# Epoch 1/5, Batch 28/106, Loss: 3.3929
# Epoch 1/5, Batch 29/106, Loss: 3.0245
# Epoch 1/5, Batch 30/106, Loss: 3.1119
# Epoch 1/5, Batch 31/106, Loss: 3.0736
# Epoch 1/5, Batch 32/106, Loss: 2.9386
# Epoch 1/5, Batch 33/106, Loss: 3.2572
# Epoch 1/5, Batch 34/106, Loss: 2.9656
# Epoch 1/5, Batch 35/106, Loss: 3.1045
# Epoch 1/5, Batch 36/106, Loss: 3.0158
# Epoch 1/5, Batch 37/106, Loss: 3.0557
# Epoch 1/5, Batch 38/106, Loss: 3.3190
# Epoch 1/5, Batch 39/106, Loss: 3.2130
# Epoch 1/5, Batch 40/106, Loss: 3.1763
# Epoch 1/5, Batch 41/106, Loss: 3.0464
# Epoch 1/5, Batch 42/106, Loss: 3.1360
# Epoch 1/5, Batch 43/106, Loss: 2.9243
# Epoch 1/5, Batch 44/106, Loss: 3.0240
# Epoch 1/5, Batch 45/106, Loss: 3.0589
# Epoch 1/5, Batch 46/106, Loss: 2.8468
# Epoch 1/5, Batch 47/106, Loss: 2.9534
# Epoch 1/5, Batch 48/106, Loss: 3.1097
# Epoch 1/5, Batch 49/106, Loss: 3.1076
# Epoch 1/5, Batch 50/106, Loss: 3.2518
# Epoch 1/5, Batch 51/106, Loss: 2.9186
# Epoch 1/5, Batch 52/106, Loss: 3.0348
# Epoch 1/5, Batch 53/106, Loss: 3.0814
# Epoch 1/5, Batch 54/106, Loss: 2.8882
# Epoch 1/5, Batch 55/106, Loss: 2.9299
# Epoch 1/5, Batch 56/106, Loss: 3.3863
# Epoch 1/5, Batch 57/106, Loss: 2.8266
# Epoch 1/5, Batch 58/106, Loss: 3.4600
# Epoch 1/5, Batch 59/106, Loss: 2.9978
# Epoch 1/5, Batch 60/106, Loss: 3.1683
# Epoch 1/5, Batch 61/106, Loss: 3.1889
# Epoch 1/5, Batch 62/106, Loss: 3.0739
# Epoch 1/5, Batch 63/106, Loss: 2.8259
# Epoch 1/5, Batch 64/106, Loss: 3.0122
# Epoch 1/5, Batch 65/106, Loss: 3.1283
# Epoch 1/5, Batch 66/106, Loss: 3.1287
# Epoch 1/5, Batch 67/106, Loss: 3.1922
# Epoch 1/5, Batch 68/106, Loss: 3.0194
# Epoch 1/5, Batch 69/106, Loss: 3.0446
# Epoch 1/5, Batch 70/106, Loss: 3.0414
# Epoch 1/5, Batch 71/106, Loss: 2.9998
# Epoch 1/5, Batch 72/106, Loss: 3.0846
# Epoch 1/5, Batch 73/106, Loss: 3.0671
# Epoch 1/5, Batch 74/106, Loss: 2.9277
# Epoch 1/5, Batch 75/106, Loss: 2.9188
# Epoch 1/5, Batch 76/106, Loss: 2.8884
# Epoch 1/5, Batch 77/106, Loss: 2.9271
# Epoch 1/5, Batch 78/106, Loss: 3.1547
# Epoch 1/5, Batch 79/106, Loss: 2.9785
# Epoch 1/5, Batch 80/106, Loss: 2.9194
# Epoch 1/5, Batch 81/106, Loss: 3.2376
# Epoch 1/5, Batch 82/106, Loss: 3.1992
# Epoch 1/5, Batch 83/106, Loss: 3.0640
# Epoch 1/5, Batch 84/106, Loss: 3.0985
# Epoch 1/5, Batch 85/106, Loss: 2.8758
# Epoch 1/5, Batch 86/106, Loss: 3.0540
# Epoch 1/5, Batch 87/106, Loss: 2.9820
# Epoch 1/5, Batch 88/106, Loss: 3.0741
# Epoch 1/5, Batch 89/106, Loss: 3.0559
# Epoch 1/5, Batch 90/106, Loss: 3.0269
# Epoch 1/5, Batch 91/106, Loss: 2.9948
# Epoch 1/5, Batch 92/106, Loss: 3.1166
# Epoch 1/5, Batch 93/106, Loss: 3.1047
# Epoch 1/5, Batch 94/106, Loss: 2.7777
# Epoch 1/5, Batch 95/106, Loss: 3.0889
# Epoch 1/5, Batch 96/106, Loss: 3.0729
# Epoch 1/5, Batch 97/106, Loss: 3.0928
# Epoch 1/5, Batch 98/106, Loss: 3.1401
# Epoch 1/5, Batch 99/106, Loss: 3.0120
# Epoch 1/5, Batch 100/106, Loss: 3.3053
# Epoch 1/5, Batch 101/106, Loss: 3.1385
# Epoch 1/5, Batch 102/106, Loss: 3.0176
# Epoch 1/5, Batch 103/106, Loss: 2.9092
# Epoch 1/5, Batch 104/106, Loss: 2.8872
# Epoch 1/5, Batch 105/106, Loss: 3.1321
# Epoch 1/5, Batch 106/106, Loss: 2.9658
# Epoch 1 completed with average loss: 3.1475
# Epoch 2/5, Batch 1/106, Loss: 3.0057
# Epoch 2/5, Batch 2/106, Loss: 2.9582
# Epoch 2/5, Batch 3/106, Loss: 2.9154
# Epoch 2/5, Batch 4/106, Loss: 3.0679
# Epoch 2/5, Batch 5/106, Loss: 3.0399
# Epoch 2/5, Batch 6/106, Loss: 2.9355
# Epoch 2/5, Batch 7/106, Loss: 3.0255
# Epoch 2/5, Batch 8/106, Loss: 2.9705
# Epoch 2/5, Batch 9/106, Loss: 2.9705
# Epoch 2/5, Batch 10/106, Loss: 2.9097
# Epoch 2/5, Batch 11/106, Loss: 2.8094
# Epoch 2/5, Batch 12/106, Loss: 3.1681
# Epoch 2/5, Batch 13/106, Loss: 2.7925
# Epoch 2/5, Batch 14/106, Loss: 2.9177
# Epoch 2/5, Batch 15/106, Loss: 3.2898
# Epoch 2/5, Batch 16/106, Loss: 3.0107
# Epoch 2/5, Batch 17/106, Loss: 2.9252
# Epoch 2/5, Batch 18/106, Loss: 2.9385
# Epoch 2/5, Batch 19/106, Loss: 2.8849
# Epoch 2/5, Batch 20/106, Loss: 3.0726
# Epoch 2/5, Batch 21/106, Loss: 2.9573
# Epoch 2/5, Batch 22/106, Loss: 3.1696
# Epoch 2/5, Batch 23/106, Loss: 3.1301
# Epoch 2/5, Batch 24/106, Loss: 2.9104
# Epoch 2/5, Batch 25/106, Loss: 2.9864
# Epoch 2/5, Batch 26/106, Loss: 2.8914
# Epoch 2/5, Batch 27/106, Loss: 2.7969
# Epoch 2/5, Batch 28/106, Loss: 3.2682
# Epoch 2/5, Batch 29/106, Loss: 3.0206
# Epoch 2/5, Batch 30/106, Loss: 3.0895
# Epoch 2/5, Batch 31/106, Loss: 2.8705
# Epoch 2/5, Batch 32/106, Loss: 2.9182
# Epoch 2/5, Batch 33/106, Loss: 2.7593
# Epoch 2/5, Batch 34/106, Loss: 2.9604
# Epoch 2/5, Batch 35/106, Loss: 3.0397
# Epoch 2/5, Batch 36/106, Loss: 3.0692
# Epoch 2/5, Batch 37/106, Loss: 3.3448
# Epoch 2/5, Batch 38/106, Loss: 2.9234
# Epoch 2/5, Batch 39/106, Loss: 3.0941
# Epoch 2/5, Batch 40/106, Loss: 2.9633
# Epoch 2/5, Batch 41/106, Loss: 3.0539
# Epoch 2/5, Batch 42/106, Loss: 2.8959
# Epoch 2/5, Batch 43/106, Loss: 3.1367
# Epoch 2/5, Batch 44/106, Loss: 2.9421
# Epoch 2/5, Batch 45/106, Loss: 3.0636
# Epoch 2/5, Batch 46/106, Loss: 3.0421
# Epoch 2/5, Batch 47/106, Loss: 2.9277
# Epoch 2/5, Batch 48/106, Loss: 3.0952
# Epoch 2/5, Batch 49/106, Loss: 3.0301
# Epoch 2/5, Batch 50/106, Loss: 2.9865
# Epoch 2/5, Batch 51/106, Loss: 2.9821
# Epoch 2/5, Batch 52/106, Loss: 3.0388
# Epoch 2/5, Batch 53/106, Loss: 3.1105
# Epoch 2/5, Batch 54/106, Loss: 3.1962
# Epoch 2/5, Batch 55/106, Loss: 3.0616
# Epoch 2/5, Batch 56/106, Loss: 3.1261
# Epoch 2/5, Batch 57/106, Loss: 2.8414
# Epoch 2/5, Batch 58/106, Loss: 3.1087
# Epoch 2/5, Batch 59/106, Loss: 2.8923
# Epoch 2/5, Batch 60/106, Loss: 2.8909
# Epoch 2/5, Batch 61/106, Loss: 3.0336
# Epoch 2/5, Batch 62/106, Loss: 3.0385
# Epoch 2/5, Batch 63/106, Loss: 2.9281
# Epoch 2/5, Batch 64/106, Loss: 2.9189
# Epoch 2/5, Batch 65/106, Loss: 2.9074
# Epoch 2/5, Batch 66/106, Loss: 2.9245
# Epoch 2/5, Batch 67/106, Loss: 3.0519
# Epoch 2/5, Batch 68/106, Loss: 3.0412
# Epoch 2/5, Batch 69/106, Loss: 3.1218
# Epoch 2/5, Batch 70/106, Loss: 2.8304
# Epoch 2/5, Batch 71/106, Loss: 2.8347
# Epoch 2/5, Batch 72/106, Loss: 2.8858
# Epoch 2/5, Batch 73/106, Loss: 3.1244
# Epoch 2/5, Batch 74/106, Loss: 2.9923
# Epoch 2/5, Batch 75/106, Loss: 2.9245
# Epoch 2/5, Batch 76/106, Loss: 2.9652
# Epoch 2/5, Batch 77/106, Loss: 3.0392
# Epoch 2/5, Batch 78/106, Loss: 2.9482
# Epoch 2/5, Batch 79/106, Loss: 2.8890
# Epoch 2/5, Batch 80/106, Loss: 2.9596
# Epoch 2/5, Batch 81/106, Loss: 2.9603
# Epoch 2/5, Batch 82/106, Loss: 3.0123
# Epoch 2/5, Batch 83/106, Loss: 3.1163
# Epoch 2/5, Batch 84/106, Loss: 3.0652
# Epoch 2/5, Batch 85/106, Loss: 3.0994
# Epoch 2/5, Batch 86/106, Loss: 2.7565
# Epoch 2/5, Batch 87/106, Loss: 3.0410
# Epoch 2/5, Batch 88/106, Loss: 2.8097
# Epoch 2/5, Batch 89/106, Loss: 2.9086
# Epoch 2/5, Batch 90/106, Loss: 2.9104
# Epoch 2/5, Batch 91/106, Loss: 3.1950
# Epoch 2/5, Batch 92/106, Loss: 2.8739
# Epoch 2/5, Batch 93/106, Loss: 2.9299
# Epoch 2/5, Batch 94/106, Loss: 2.8560
# Epoch 2/5, Batch 95/106, Loss: 2.7995
# Epoch 2/5, Batch 96/106, Loss: 2.9215
# Epoch 2/5, Batch 97/106, Loss: 2.7229
# Epoch 2/5, Batch 98/106, Loss: 3.0302
# Epoch 2/5, Batch 99/106, Loss: 3.2341
# Epoch 2/5, Batch 100/106, Loss: 3.4816
# Epoch 2/5, Batch 101/106, Loss: 2.8614
# Epoch 2/5, Batch 102/106, Loss: 2.9829
# Epoch 2/5, Batch 103/106, Loss: 3.1516
# Epoch 2/5, Batch 104/106, Loss: 2.8738
# Epoch 2/5, Batch 105/106, Loss: 2.8548
# Epoch 2/5, Batch 106/106, Loss: 3.0684
# Epoch 2 completed with average loss: 2.9912
# Epoch 3/5, Batch 1/106, Loss: 2.8955
# Epoch 3/5, Batch 2/106, Loss: 2.9753
# Epoch 3/5, Batch 3/106, Loss: 3.0744
# Epoch 3/5, Batch 4/106, Loss: 3.1746
# Epoch 3/5, Batch 5/106, Loss: 3.1477
# Epoch 3/5, Batch 6/106, Loss: 2.8792
# Epoch 3/5, Batch 7/106, Loss: 3.0757
# Epoch 3/5, Batch 8/106, Loss: 2.8938
# Epoch 3/5, Batch 9/106, Loss: 2.9499
# Epoch 3/5, Batch 10/106, Loss: 2.8620
# Epoch 3/5, Batch 11/106, Loss: 2.9649
# Epoch 3/5, Batch 12/106, Loss: 2.9514
# Epoch 3/5, Batch 13/106, Loss: 2.9035
# Epoch 3/5, Batch 14/106, Loss: 2.8426
# Epoch 3/5, Batch 15/106, Loss: 3.0743
# Epoch 3/5, Batch 16/106, Loss: 2.8599
# Epoch 3/5, Batch 17/106, Loss: 2.8951
# Epoch 3/5, Batch 18/106, Loss: 2.9070
# Epoch 3/5, Batch 19/106, Loss: 2.9131
# Epoch 3/5, Batch 20/106, Loss: 2.9448
# Epoch 3/5, Batch 21/106, Loss: 2.9345
# Epoch 3/5, Batch 22/106, Loss: 2.9354
# Epoch 3/5, Batch 23/106, Loss: 2.9096
# Epoch 3/5, Batch 24/106, Loss: 2.8953
# Epoch 3/5, Batch 25/106, Loss: 2.8941
# Epoch 3/5, Batch 26/106, Loss: 2.9254
# Epoch 3/5, Batch 27/106, Loss: 2.9010
# Epoch 3/5, Batch 28/106, Loss: 2.8798
# Epoch 3/5, Batch 29/106, Loss: 2.9597
# Epoch 3/5, Batch 30/106, Loss: 2.7495
# Epoch 3/5, Batch 31/106, Loss: 3.1879
# Epoch 3/5, Batch 32/106, Loss: 2.7364
# Epoch 3/5, Batch 33/106, Loss: 2.7821
# Epoch 3/5, Batch 34/106, Loss: 2.7590
# Epoch 3/5, Batch 35/106, Loss: 2.9331
# Epoch 3/5, Batch 36/106, Loss: 2.9256
# Epoch 3/5, Batch 37/106, Loss: 2.9104
# Epoch 3/5, Batch 38/106, Loss: 2.9499
# Epoch 3/5, Batch 39/106, Loss: 2.9140
# Epoch 3/5, Batch 40/106, Loss: 2.9287
# Epoch 3/5, Batch 41/106, Loss: 2.9717
# Epoch 3/5, Batch 42/106, Loss: 2.9854
# Epoch 3/5, Batch 43/106, Loss: 2.9860
# Epoch 3/5, Batch 44/106, Loss: 2.7853
# Epoch 3/5, Batch 45/106, Loss: 2.9154
# Epoch 3/5, Batch 46/106, Loss: 2.8838
# Epoch 3/5, Batch 47/106, Loss: 2.8202
# Epoch 3/5, Batch 48/106, Loss: 3.0467
# Epoch 3/5, Batch 49/106, Loss: 2.9346
# Epoch 3/5, Batch 50/106, Loss: 3.0849
# Epoch 3/5, Batch 51/106, Loss: 3.0976
# Epoch 3/5, Batch 52/106, Loss: 2.7909
# Epoch 3/5, Batch 53/106, Loss: 2.9974
# Epoch 3/5, Batch 54/106, Loss: 2.9684
# Epoch 3/5, Batch 55/106, Loss: 3.1082
# Epoch 3/5, Batch 56/106, Loss: 3.0761
# Epoch 3/5, Batch 57/106, Loss: 3.0111
# Epoch 3/5, Batch 58/106, Loss: 2.7615
# Epoch 3/5, Batch 59/106, Loss: 3.0376
# Epoch 3/5, Batch 60/106, Loss: 2.9523
# Epoch 3/5, Batch 61/106, Loss: 2.9415
# Epoch 3/5, Batch 62/106, Loss: 2.9550
# Epoch 3/5, Batch 63/106, Loss: 3.0275
# Epoch 3/5, Batch 64/106, Loss: 2.9379
# Epoch 3/5, Batch 65/106, Loss: 2.8678
# Epoch 3/5, Batch 66/106, Loss: 3.1112
# Epoch 3/5, Batch 67/106, Loss: 2.9742
# Epoch 3/5, Batch 68/106, Loss: 2.9974
# Epoch 3/5, Batch 69/106, Loss: 2.9019
# Epoch 3/5, Batch 70/106, Loss: 3.0369
# Epoch 3/5, Batch 71/106, Loss: 3.0387
# Epoch 3/5, Batch 72/106, Loss: 3.1368
# Epoch 3/5, Batch 73/106, Loss: 3.0472
# Epoch 3/5, Batch 74/106, Loss: 2.8245
# Epoch 3/5, Batch 75/106, Loss: 2.9151
# Epoch 3/5, Batch 76/106, Loss: 2.9590
# Epoch 3/5, Batch 77/106, Loss: 3.1557
# Epoch 3/5, Batch 78/106, Loss: 2.9577
# Epoch 3/5, Batch 79/106, Loss: 3.0101
# Epoch 3/5, Batch 80/106, Loss: 2.9021
# Epoch 3/5, Batch 81/106, Loss: 2.8440
# Epoch 3/5, Batch 82/106, Loss: 2.9757
# Epoch 3/5, Batch 83/106, Loss: 3.0566
# Epoch 3/5, Batch 84/106, Loss: 2.8449
# Epoch 3/5, Batch 85/106, Loss: 2.7312
# Epoch 3/5, Batch 86/106, Loss: 3.0243
# Epoch 3/5, Batch 87/106, Loss: 2.8376
# Epoch 3/5, Batch 88/106, Loss: 2.9135
# Epoch 3/5, Batch 89/106, Loss: 3.0138
# Epoch 3/5, Batch 90/106, Loss: 3.1502
# Epoch 3/5, Batch 91/106, Loss: 2.9012
# Epoch 3/5, Batch 92/106, Loss: 2.9838
# Epoch 3/5, Batch 93/106, Loss: 2.8310
# Epoch 3/5, Batch 94/106, Loss: 3.1629
# Epoch 3/5, Batch 95/106, Loss: 3.1741
# Epoch 3/5, Batch 96/106, Loss: 2.9518
# Epoch 3/5, Batch 97/106, Loss: 2.8613
# Epoch 3/5, Batch 98/106, Loss: 3.0135
# Epoch 3/5, Batch 99/106, Loss: 3.0240
# Epoch 3/5, Batch 100/106, Loss: 3.0294
# Epoch 3/5, Batch 101/106, Loss: 3.0509
# Epoch 3/5, Batch 102/106, Loss: 2.9177
# Epoch 3/5, Batch 103/106, Loss: 3.1849
# Epoch 3/5, Batch 104/106, Loss: 2.9593
# Epoch 3/5, Batch 105/106, Loss: 2.9715
# Epoch 3/5, Batch 106/106, Loss: 3.0582
# Epoch 3 completed with average loss: 2.9583
# Epoch 4/5, Batch 1/106, Loss: 3.1571
# Epoch 4/5, Batch 2/106, Loss: 2.8860
# Epoch 4/5, Batch 3/106, Loss: 2.9736
# Epoch 4/5, Batch 4/106, Loss: 3.0906
# Epoch 4/5, Batch 5/106, Loss: 3.0621
# Epoch 4/5, Batch 6/106, Loss: 2.8890
# Epoch 4/5, Batch 7/106, Loss: 2.9546
# Epoch 4/5, Batch 8/106, Loss: 2.8646
# Epoch 4/5, Batch 9/106, Loss: 2.9581
# Epoch 4/5, Batch 10/106, Loss: 2.9367
# Epoch 4/5, Batch 11/106, Loss: 3.0957
# Epoch 4/5, Batch 12/106, Loss: 3.0011
# Epoch 4/5, Batch 13/106, Loss: 2.9259
# Epoch 4/5, Batch 14/106, Loss: 2.9582
# Epoch 4/5, Batch 15/106, Loss: 2.9239
# Epoch 4/5, Batch 16/106, Loss: 3.0077
# Epoch 4/5, Batch 17/106, Loss: 2.7240
# Epoch 4/5, Batch 18/106, Loss: 3.1094
# Epoch 4/5, Batch 19/106, Loss: 3.2682
# Epoch 4/5, Batch 20/106, Loss: 2.7960
# Epoch 4/5, Batch 21/106, Loss: 3.0759
# Epoch 4/5, Batch 22/106, Loss: 2.9646
# Epoch 4/5, Batch 23/106, Loss: 2.9460
# Epoch 4/5, Batch 24/106, Loss: 2.8439
# Epoch 4/5, Batch 25/106, Loss: 2.9251
# Epoch 4/5, Batch 26/106, Loss: 2.9564
# Epoch 4/5, Batch 27/106, Loss: 2.9954
# Epoch 4/5, Batch 28/106, Loss: 3.1440
# Epoch 4/5, Batch 29/106, Loss: 2.6846
# Epoch 4/5, Batch 30/106, Loss: 2.9800
# Epoch 4/5, Batch 31/106, Loss: 2.9017
# Epoch 4/5, Batch 32/106, Loss: 2.9500
# Epoch 4/5, Batch 33/106, Loss: 2.8812
# Epoch 4/5, Batch 34/106, Loss: 2.9192
# Epoch 4/5, Batch 35/106, Loss: 3.0075
# Epoch 4/5, Batch 36/106, Loss: 3.1167
# Epoch 4/5, Batch 37/106, Loss: 2.7502
# Epoch 4/5, Batch 38/106, Loss: 2.9849
# Epoch 4/5, Batch 39/106, Loss: 2.9013
# Epoch 4/5, Batch 40/106, Loss: 2.8061
# Epoch 4/5, Batch 41/106, Loss: 2.8898
# Epoch 4/5, Batch 42/106, Loss: 2.8372
# Epoch 4/5, Batch 43/106, Loss: 3.0309
# Epoch 4/5, Batch 44/106, Loss: 3.0129
# Epoch 4/5, Batch 45/106, Loss: 2.9232
# Epoch 4/5, Batch 46/106, Loss: 2.8408
# Epoch 4/5, Batch 47/106, Loss: 2.8583
# Epoch 4/5, Batch 48/106, Loss: 2.9286
# Epoch 4/5, Batch 49/106, Loss: 3.0703
# Epoch 4/5, Batch 50/106, Loss: 2.8684
# Epoch 4/5, Batch 51/106, Loss: 3.1190
# Epoch 4/5, Batch 52/106, Loss: 2.7490
# Epoch 4/5, Batch 53/106, Loss: 2.9647
# Epoch 4/5, Batch 54/106, Loss: 2.9420
# Epoch 4/5, Batch 55/106, Loss: 3.0213
# Epoch 4/5, Batch 56/106, Loss: 2.7421
# Epoch 4/5, Batch 57/106, Loss: 3.0980
# Epoch 4/5, Batch 58/106, Loss: 3.0345
# Epoch 4/5, Batch 59/106, Loss: 2.9541
# Epoch 4/5, Batch 60/106, Loss: 2.9358
# Epoch 4/5, Batch 61/106, Loss: 2.7971
# Epoch 4/5, Batch 62/106, Loss: 2.7200
# Epoch 4/5, Batch 63/106, Loss: 3.0626
# Epoch 4/5, Batch 64/106, Loss: 2.8751
# Epoch 4/5, Batch 65/106, Loss: 2.7979
# Epoch 4/5, Batch 66/106, Loss: 3.0020
# Epoch 4/5, Batch 67/106, Loss: 2.7802
# Epoch 4/5, Batch 68/106, Loss: 3.1027
# Epoch 4/5, Batch 69/106, Loss: 2.8942
# Epoch 4/5, Batch 70/106, Loss: 3.0212
# Epoch 4/5, Batch 71/106, Loss: 2.9183
# Epoch 4/5, Batch 72/106, Loss: 2.8665
# Epoch 4/5, Batch 73/106, Loss: 2.9406
# Epoch 4/5, Batch 74/106, Loss: 2.9403
# Epoch 4/5, Batch 75/106, Loss: 3.0063
# Epoch 4/5, Batch 76/106, Loss: 2.9874
# Epoch 4/5, Batch 77/106, Loss: 2.9763
# Epoch 4/5, Batch 78/106, Loss: 3.1191
# Epoch 4/5, Batch 79/106, Loss: 2.9313
# Epoch 4/5, Batch 80/106, Loss: 2.8276
# Epoch 4/5, Batch 81/106, Loss: 3.0642
# Epoch 4/5, Batch 82/106, Loss: 2.8990
# Epoch 4/5, Batch 83/106, Loss: 2.9251
# Epoch 4/5, Batch 84/106, Loss: 2.8002
# Epoch 4/5, Batch 85/106, Loss: 3.1497
# Epoch 4/5, Batch 86/106, Loss: 2.7895
# Epoch 4/5, Batch 87/106, Loss: 2.9244
# Epoch 4/5, Batch 88/106, Loss: 3.0425
# Epoch 4/5, Batch 89/106, Loss: 2.9381
# Epoch 4/5, Batch 90/106, Loss: 3.0080
# Epoch 4/5, Batch 91/106, Loss: 2.9890
# Epoch 4/5, Batch 92/106, Loss: 3.1024
# Epoch 4/5, Batch 93/106, Loss: 2.9780
# Epoch 4/5, Batch 94/106, Loss: 2.9925
# Epoch 4/5, Batch 95/106, Loss: 2.9793
# Epoch 4/5, Batch 96/106, Loss: 3.2771
# Epoch 4/5, Batch 97/106, Loss: 3.0601
# Epoch 4/5, Batch 98/106, Loss: 2.9172
# Epoch 4/5, Batch 99/106, Loss: 2.9197
# Epoch 4/5, Batch 100/106, Loss: 2.8006
# Epoch 4/5, Batch 101/106, Loss: 3.0174
# Epoch 4/5, Batch 102/106, Loss: 2.8982
# Epoch 4/5, Batch 103/106, Loss: 2.9454
# Epoch 4/5, Batch 104/106, Loss: 3.0848
# Epoch 4/5, Batch 105/106, Loss: 3.1730
# Epoch 4/5, Batch 106/106, Loss: 2.9075
# Epoch 4 completed with average loss: 2.9555
# Epoch 5/5, Batch 1/106, Loss: 2.9324
# Epoch 5/5, Batch 2/106, Loss: 2.9721
# Epoch 5/5, Batch 3/106, Loss: 3.1716
# Epoch 5/5, Batch 4/106, Loss: 3.0829
# Epoch 5/5, Batch 5/106, Loss: 2.8562
# Epoch 5/5, Batch 6/106, Loss: 2.8955
# Epoch 5/5, Batch 7/106, Loss: 2.9474
# Epoch 5/5, Batch 8/106, Loss: 2.7313
# Epoch 5/5, Batch 9/106, Loss: 2.7777
# Epoch 5/5, Batch 10/106, Loss: 3.0222
# Epoch 5/5, Batch 11/106, Loss: 2.8548
# Epoch 5/5, Batch 12/106, Loss: 3.0863
# Epoch 5/5, Batch 13/106, Loss: 2.8198
# Epoch 5/5, Batch 14/106, Loss: 2.7450
# Epoch 5/5, Batch 15/106, Loss: 3.0323
# Epoch 5/5, Batch 16/106, Loss: 3.0438
# Epoch 5/5, Batch 17/106, Loss: 2.7572
# Epoch 5/5, Batch 18/106, Loss: 2.8787
# Epoch 5/5, Batch 19/106, Loss: 3.0648
# Epoch 5/5, Batch 20/106, Loss: 3.0302
# Epoch 5/5, Batch 21/106, Loss: 2.8495
# Epoch 5/5, Batch 22/106, Loss: 2.8925
# Epoch 5/5, Batch 23/106, Loss: 3.0138
# Epoch 5/5, Batch 24/106, Loss: 2.8657
# Epoch 5/5, Batch 25/106, Loss: 3.1457
# Epoch 5/5, Batch 26/106, Loss: 2.9672
# Epoch 5/5, Batch 27/106, Loss: 3.0977
# Epoch 5/5, Batch 28/106, Loss: 3.1046
# Epoch 5/5, Batch 29/106, Loss: 2.9092
# Epoch 5/5, Batch 30/106, Loss: 3.1063
# Epoch 5/5, Batch 31/106, Loss: 3.1340
# Epoch 5/5, Batch 32/106, Loss: 2.9508
# Epoch 5/5, Batch 33/106, Loss: 2.8427
# Epoch 5/5, Batch 34/106, Loss: 2.9895
# Epoch 5/5, Batch 35/106, Loss: 3.1524
# Epoch 5/5, Batch 36/106, Loss: 2.8105
# Epoch 5/5, Batch 37/106, Loss: 2.9918
# Epoch 5/5, Batch 38/106, Loss: 2.9226
# Epoch 5/5, Batch 39/106, Loss: 2.9338
# Epoch 5/5, Batch 40/106, Loss: 3.0865
# Epoch 5/5, Batch 41/106, Loss: 2.9358
# Epoch 5/5, Batch 42/106, Loss: 2.7918
# Epoch 5/5, Batch 43/106, Loss: 2.9921
# Epoch 5/5, Batch 44/106, Loss: 2.8237
# Epoch 5/5, Batch 45/106, Loss: 2.7481
# Epoch 5/5, Batch 46/106, Loss: 3.0035
# Epoch 5/5, Batch 47/106, Loss: 2.8496
# Epoch 5/5, Batch 48/106, Loss: 3.0108
# Epoch 5/5, Batch 49/106, Loss: 3.1787
# Epoch 5/5, Batch 50/106, Loss: 2.7513
# Epoch 5/5, Batch 51/106, Loss: 2.7670
# Epoch 5/5, Batch 52/106, Loss: 2.9310
# Epoch 5/5, Batch 53/106, Loss: 2.7524
# Epoch 5/5, Batch 54/106, Loss: 2.8046
# Epoch 5/5, Batch 55/106, Loss: 2.8258
# Epoch 5/5, Batch 56/106, Loss: 2.9465
# Epoch 5/5, Batch 57/106, Loss: 2.8489
# Epoch 5/5, Batch 58/106, Loss: 2.9585
# Epoch 5/5, Batch 59/106, Loss: 2.8969
# Epoch 5/5, Batch 60/106, Loss: 2.9007
# Epoch 5/5, Batch 61/106, Loss: 2.7133
# Epoch 5/5, Batch 62/106, Loss: 2.8559
# Epoch 5/5, Batch 63/106, Loss: 3.0198
# Epoch 5/5, Batch 64/106, Loss: 2.8458
# Epoch 5/5, Batch 65/106, Loss: 3.0029
# Epoch 5/5, Batch 66/106, Loss: 3.0214
# Epoch 5/5, Batch 67/106, Loss: 2.8127
# Epoch 5/5, Batch 68/106, Loss: 2.8900
# Epoch 5/5, Batch 69/106, Loss: 2.7563
# Epoch 5/5, Batch 70/106, Loss: 2.9831
# Epoch 5/5, Batch 71/106, Loss: 2.7975
# Epoch 5/5, Batch 72/106, Loss: 2.9368
# Epoch 5/5, Batch 73/106, Loss: 3.0282
# Epoch 5/5, Batch 74/106, Loss: 2.6571
# Epoch 5/5, Batch 75/106, Loss: 2.9973
# Epoch 5/5, Batch 76/106, Loss: 2.9801
# Epoch 5/5, Batch 77/106, Loss: 2.9610
# Epoch 5/5, Batch 78/106, Loss: 2.9032
# Epoch 5/5, Batch 79/106, Loss: 2.8174
# Epoch 5/5, Batch 80/106, Loss: 2.8879
# Epoch 5/5, Batch 81/106, Loss: 2.7935
# Epoch 5/5, Batch 82/106, Loss: 2.9370
# Epoch 5/5, Batch 83/106, Loss: 2.9418
# Epoch 5/5, Batch 84/106, Loss: 2.7689
# Epoch 5/5, Batch 85/106, Loss: 3.1408
# Epoch 5/5, Batch 86/106, Loss: 2.8795
# Epoch 5/5, Batch 87/106, Loss: 3.0128
# Epoch 5/5, Batch 88/106, Loss: 3.0978
# Epoch 5/5, Batch 89/106, Loss: 3.0231
# Epoch 5/5, Batch 90/106, Loss: 2.8243
# Epoch 5/5, Batch 91/106, Loss: 2.8243
# Epoch 5/5, Batch 92/106, Loss: 3.3175
# Epoch 5/5, Batch 93/106, Loss: 2.8442
# Epoch 5/5, Batch 94/106, Loss: 2.9121
# Epoch 5/5, Batch 95/106, Loss: 2.8603
# Epoch 5/5, Batch 96/106, Loss: 2.9452
# Epoch 5/5, Batch 97/106, Loss: 3.0269
# Epoch 5/5, Batch 98/106, Loss: 3.0385
# Epoch 5/5, Batch 99/106, Loss: 3.1198
# Epoch 5/5, Batch 100/106, Loss: 3.1196
# Epoch 5/5, Batch 101/106, Loss: 3.0305
# Epoch 5/5, Batch 102/106, Loss: 2.9099
# Epoch 5/5, Batch 103/106, Loss: 2.9675
# Epoch 5/5, Batch 104/106, Loss: 2.8678
# Epoch 5/5, Batch 105/106, Loss: 2.8518
# Epoch 5/5, Batch 106/106, Loss: 2.9952
# Epoch 5 completed with average loss: 2.9349

# %% [markdown]
# played a bit with resnet18 on GPU accelerated system; based on only parameter increase these are the expected timings:
# | Model        | Parameters (Millions) | Expected Time (minutes) | Time Factor (compared to ResNet-18) |
# |--------------|-----------------------|-------------------------|-------------------------------------|
# | ResNet-18    | 11.7                  | 28.45                   | 1x                                  |
# | ResNet-34    | 21.8                  | 56.35                   | 1.98x                               |
# | ResNet-50    | 25.6                  | 63.51                   | 2.23x                               |
# | ResNet-101   | 44.6                  | 112.34                  | 3.95x                               |
# | ResNet-110   | 1.7                   | 4.44                    | 0.16x                               |
# | ResNet-152   | 60.2                  | 148.95                  | 5.24x                               |
# | ResNet-164   | 65.6                  | 157.31                  | 5.53x                               |
# | ResNet-1202  | 1700                  | 4108.97                 | 144.54x                             |

# %%
modeldir = os.path.join(config.get('directories', 'root_dir'), 'models/pytorch/brand_predictor_resnet50.pth')
os.makedirs(os.path.dirname(modeldir), exist_ok=True)
# Save Model
torch.save(model.state_dict(), modeldir)
print("Training complete and model saved to ", modeldir)
# Out:
# Training complete and model saved to  /home/frederic/Documents/automotive_project/models/pytorch/brand_predictor_resnet50.pth

# %%
##use the saved model to make random predictions: 
model = models.resnet50()
model.fc = torch.nn.Linear(model.fc.in_features, 30)
model.load_state_dict(torch.load(modeldir))
# Out:
# /tmp/ipykernel_82277/2158946691.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(modeldir))
# <All keys matched successfully>

# %%
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=30, bias=True)
# )

# %%
random_testdata = db.execute_query("""SELECT
                            images.yolobox_top_left_x, 
                            images.yolobox_top_left_y, 
                            images.yolobox_bottom_right_x, 
                            images.yolobox_bottom_right_y, 
                            images.image_path, 
                            listings.brand
                        FROM images 
                        JOIN listings ON listings.id = images.listing_id
                        WHERE 
                            listings.countrycode = 'F' """)
labeled_data_random = pd.DataFrame(random_testdata).fillna(-1)
labeled_data_random = bbox_to_ints(labeled_data_random)
#model was trained on a random sample of cars listed in B(elgium); 
#to make sure we test on unseen data; get a sample fo all cars lsited in F(rance)

# %%
len(labeled_data_random)
# Out:
# 1229702

# %%
random_selection = 500000
random_images_to_predict = labeled_data_random.sample(random_selection)
random_images_to_predict["image_path"] = random_images_to_predict["image_path"].apply(lambda x: x.replace('\\', '/'))
random_images_to_predict["abs_image_path"]= basedir + '/' + random_images_to_predict["image_path"]

# %%
results = []
for row in random_images_to_predict.iterrows():
    
    #make a function that does the image preprocessing like you fed it into the pytorch model: 
    # Example path to an image
    row = row[1]
    img_path = row['abs_image_path'] 
    label = row['brand']
    x1 = row['yolobox_top_left_x']
    y1 = row['yolobox_top_left_y']
    x2 = row['yolobox_bottom_right_x']
    y2 = row['yolobox_bottom_right_y']
    
    # Load image
    image = Image.open(img_path).convert('RGB')
    #BBOX was used on training, so here too:
    if use_bbox and x1 != -1:
        image = image.crop((x1, y1, x2, y2))
    # Apply transformations if any
    # We'll reuse the SAME transformation as before! see the cell where transform is declared. 
    image = transform(image)

    # Add an extra batch dimension since the model expects a batch of images (even if it's just one)
    image = image.unsqueeze(0)  # Shape: [1, 3, 224, 224]

    #make prediciton: 
    with torch.no_grad():  # Disable gradient calculation (faster, no backpropagation needed)
        output = model(image)
    probabilities = torch.nn.functional.softmax(output, dim=1)
    _, predicted_class = torch.max(probabilities, 1)
    predicted_label = brand_encoder.classes_[predicted_class.item()]
    certainty = probabilities[0, predicted_class].item()
    results.append([img_path, label, predicted_label, certainty])

# %%
results = pd.DataFrame(results, columns=['image_path', 'brand', 'prediction', 'certainty'])

# %%
x,y= [4,4]
fig, axes = plt.subplots(x, y, figsize=(12, 12))
axes = axes.flatten()

for i, (index, row) in enumerate(results.sample(x*y).iterrows()):
    image_path = row['image_path']
    brand = row['brand']
    prediction = row['prediction']
    certainty = row['certainty']
    img = Image.open(image_path)
    axes[i].imshow(img)
    axes[i].set_title(f"{brand}: ({prediction}, {certainty:.2f})", fontsize=10)
    axes[i].axis('off')
plt.suptitle('Random grid of results')
plt.tight_layout()
plt.show()

# %%
cm = implot.make_cm(results['brand'], results['prediction'], results['brand'].unique())
cm.title('Just a result (expected bad outcome here.)')
;
# Out:
# ''

# %% [markdown]
# # Horrible results.
#
# Question for you: WHY?
# - Tip: What kind of preprocessing have I forgotten?
