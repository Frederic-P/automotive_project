# %% [markdown]
# # 3.3 Brand classification with transfer learning and angle information.
# This notebooko will train all thirty brands on the data using RESNET50 (transfer learning); based on the crop-conclusion from notebook `3.2`.
#
# This notebook has a COLAB variant after GPU decided to commit harakiri. - Training for phase 3.3 has moved to there; to fit in the restricted space available on google, trainingdata was pre-processed (cropped to bounding bouxes, resized to resnet shape) using notebook `'../to_colab.ipynb'`.

# %%
import pandas as pd
import os
import sys
sys.path.append('../../utils')
import config_handling as conf
import cnn_helpers
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
import tensorflow as tf


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score, cohen_kappa_score
# Out:
# 2025-03-15 17:33:17.105699: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## 3.3.1 Preparing the system
# - Setting constants to us in this notebook and GPU override.
# - Reading config file - no database connection needed as data comes from CSVs
# - Add the `CROP` constant

# %%
SHAPE = 224   #required for resnet
BATCH_SIZE = 32     #how big ar teh batches for the online learning part
MAX_EPOCHS = 100    #upper limit of epochs per learning task - 
                    #    NOTE THAT there is early stopping and lr plateau just as in nobteook 2.
CROP = True         #Based on notebook 3.2

# %%
cnn_helpers.system_override()
device = cnn_helpers.system_pick_device()
# Out:
# System override applied - check if GPU is detected
# Using GPU for deep learning.
# 2025-03-15 17:33:26.227093: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-03-15 17:33:28.419673: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-03-15 17:33:28.419768: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
config = conf.read_config('../../config/automotive.conf.ini')
basedir = config['settings']['image_directory']

augment_base = os.path.join(basedir, 'augmentated data', 'brand phase')
augment_csv_dump = os.path.join(basedir, 'CSV-data', 'brand phase')

logfile = os.path.join(config['directories']['root_dir'], 'logging', 'angle_brand_trainingslog.txt')

# %% [markdown]
# ## 3.3.2 Data loading
# Load the CSV's generated by step 3.1 into memory.
#
# If KERAS would've been able of using integers; then the 300.000 images per angle would've fit in memory: you'd need about 45GB; with the floats however you need about 4 times more! So here too you'll be required to use batch learning.

# %%
traindata = pd.read_csv(os.path.join(augment_csv_dump, 'traindata_brandphase.csv'))
testdata = pd.read_csv(os.path.join(augment_csv_dump, 'testdata_brandphase.csv'))

# %%
angles = traindata['model_label'].unique()

# %% [markdown]
# ## 3.3.3 Label encoding
# Now we need to use full label encoding for all thirty brands.

# %%
#make an encoder: 
#   LabelEncoder sorts alphabetically and since all classes are always in the traindata, these numbers
#   can be considered stable.
brands = traindata.brand.unique()
label_encoder = LabelEncoder()
label_encoder.fit(brands)
# Out:
# LabelEncoder()

# %%
#apply label encoding on train and test dataframes. 
traindata['y_encoded'] = label_encoder.transform(traindata['brand'])
testdata['y_encoded'] = label_encoder.transform(testdata['brand'])

# %% [markdown]
# ## 3.3.4 Shuffle data:
# Shuffle train and test data; technically not really needed as the generators yield random indexes, but whatever.

# %%
#shuffle
testdata = cnn_helpers.shuffle_df(testdata)
traindata = cnn_helpers.shuffle_df(traindata)

# %%
#Xy (remember that a representative train test split was done in notebook 3.1)
#   we are just using the same split and augmentation data across notebook 3.2, 3.3, 3.4 and 3.5!!

# %% [markdown]
# ## 3.3.5 Starting a training loop:
# Everything is ready to go for training, GPU is set up, data is split, shuffled and encoded, all utilities are made in phase `3.2`. We just need to pay special attention to the loop for training, the aim is to train one angle, save the model and then the next. If the training loop crashes while making the n-th angle, it should not retrain the already finished angles. This is easily implemented using a simple `listdir()` statement.

# %%
angles = traindata.model_label.unique()

model_dest_dir = os.path.join(os.getcwd(), '..', '..', 'models', 'ALL_brand_models_angled')
os.makedirs(model_dest_dir, exist_ok=True)

for angle in angles: 
    #check if angle is trained already: 
    name = f'FULL_brand_model-Resnet50_cropped={CROP}_angle={angle}.keras'
    if name in os.listdir(model_dest_dir):
        print(f"Skipping {name} -- model already trained")
        continue
    cnn_helpers.write_msg_to_log('Started training model: '+name, logfile)
    view_by_angle_test = testdata.query('model_label==@angle').reset_index()
    #Angle is not trained yet: query it from train and test:
    view_by_angle_train = traindata.query('model_label==@angle').reset_index()
    #reduce validation data; is a big bottleneck in performance, still well over 10% of the trainingset
    reduction_key = 'brand'
    factor = round((len(view_by_angle_train)*0.12)/view_by_angle_train[reduction_key].nunique())
    view_by_angle_test_reduced = cnn_helpers.reducer(view_by_angle_test, factor, reduction_key)
    #Get X,y for train and test of the angle view: 
    X_train, y_train = cnn_helpers.get_X_y(view_by_angle_train, 'y_encoded', ['brand'])
    X_test, y_test = cnn_helpers.get_X_y(view_by_angle_test_reduced, 'y_encoded', ['brand'])
    model = cnn_helpers.resnet_learner(X_train, X_test, y_train, y_test, SHAPE, CROP, model_dest_dir, BATCH_SIZE, MAX_EPOCHS, logfile)
    model.save(os.path.join(model_dest_dir, name))
    cnn_helpers.write_msg_to_log('Finished raining model: '+name, logfile)
# Out:
# 2025-03-15 17:33:52.202980: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-03-15 17:33:52.203113: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-03-15 17:33:52.203165: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-03-15 17:33:52.203250: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-03-15 17:33:52.203304: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-03-15 17:33:52.203358: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:920] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-03-15 17:33:52.203372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11236 MB memory:  -> device: 0, name: AMD Radeon RX 6700 XT, pci bus id: 0000:2d:00.0
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742056437.344967    6374 service.cc:146] XLA service 0x759da8002ac0 initialized for platform ROCM (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742056437.345005    6374 service.cc:154]   StreamExecutor device (0): AMD Radeon RX 6700 XT, AMDGPU ISA version: gfx1030
# 2025-03-15 17:33:57.443825: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#    1/9375 ━━━━━━━━━━━━━━━━━━━━ 19:12:03 7s/step - accuracy: 0.0000e+00 - loss: 3.9727
# I0000 00:00:1742056441.174525    6374 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1449s 154ms/step - accuracy: 0.0624 - loss: 3.3225 - val_accuracy: 0.0708 - val_loss: 3.1888 - learning_rate: 0.0010
# Epoch 2/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1267s 135ms/step - accuracy: 0.1089 - loss: 3.1265 - val_accuracy: 0.0786 - val_loss: 3.2259 - learning_rate: 0.0010
# Epoch 3/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1269s 135ms/step - accuracy: 0.1225 - loss: 3.0583 - val_accuracy: 0.0869 - val_loss: 3.0875 - learning_rate: 0.0010
# Epoch 4/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1278s 136ms/step - accuracy: 0.1328 - loss: 3.0207 - val_accuracy: 0.0860 - val_loss: 3.1409 - learning_rate: 0.0010
# Epoch 5/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1278s 136ms/step - accuracy: 0.1411 - loss: 2.9906 - val_accuracy: 0.0959 - val_loss: 3.0792 - learning_rate: 0.0010
# Epoch 6/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1284s 137ms/step - accuracy: 0.1455 - loss: 2.9671 - val_accuracy: 0.1023 - val_loss: 3.0507 - learning_rate: 0.0010
# Epoch 7/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1280s 137ms/step - accuracy: 0.1497 - loss: 2.9425 - val_accuracy: 0.0936 - val_loss: 3.0809 - learning_rate: 0.0010
# Epoch 8/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1878s 200ms/step - accuracy: 0.1539 - loss: 2.9319 - val_accuracy: 0.0736 - val_loss: 3.1697 - learning_rate: 0.0010
# Epoch 9/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.1563 - loss: 2.9183
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1294s 138ms/step - accuracy: 0.1563 - loss: 2.9183 - val_accuracy: 0.0784 - val_loss: 3.1502 - learning_rate: 0.0010
# Epoch 10/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1294s 138ms/step - accuracy: 0.1638 - loss: 2.8884 - val_accuracy: 0.0867 - val_loss: 3.1031 - learning_rate: 5.0000e-04
# Epoch 11/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1292s 138ms/step - accuracy: 0.1652 - loss: 2.8823 - val_accuracy: 0.1065 - val_loss: 3.0057 - learning_rate: 5.0000e-04
# Epoch 12/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1304s 139ms/step - accuracy: 0.1675 - loss: 2.8769 - val_accuracy: 0.1041 - val_loss: 3.0325 - learning_rate: 5.0000e-04
# Epoch 13/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1302s 139ms/step - accuracy: 0.1673 - loss: 2.8734 - val_accuracy: 0.1002 - val_loss: 3.0520 - learning_rate: 5.0000e-04
# Epoch 14/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.1703 - loss: 2.8671
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1294s 138ms/step - accuracy: 0.1703 - loss: 2.8671 - val_accuracy: 0.0835 - val_loss: 3.1254 - learning_rate: 5.0000e-04
# Epoch 15/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1294s 138ms/step - accuracy: 0.1729 - loss: 2.8559 - val_accuracy: 0.0972 - val_loss: 3.0439 - learning_rate: 2.5000e-04
# Epoch 16/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1294s 138ms/step - accuracy: 0.1717 - loss: 2.8563 - val_accuracy: 0.0987 - val_loss: 3.0478 - learning_rate: 2.5000e-04
# Epoch 17/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1287s 137ms/step - accuracy: 0.1755 - loss: 2.8465 - val_accuracy: 0.1095 - val_loss: 2.9943 - learning_rate: 2.5000e-04
# Epoch 18/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1286s 137ms/step - accuracy: 0.1755 - loss: 2.8481 - val_accuracy: 0.0995 - val_loss: 3.0369 - learning_rate: 2.5000e-04
# Epoch 19/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1285s 137ms/step - accuracy: 0.1760 - loss: 2.8462 - val_accuracy: 0.1026 - val_loss: 3.0387 - learning_rate: 2.5000e-04
# Epoch 20/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.1747 - loss: 2.8440
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1291s 138ms/step - accuracy: 0.1747 - loss: 2.8440 - val_accuracy: 0.0946 - val_loss: 3.0646 - learning_rate: 2.5000e-04
# Epoch 21/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1289s 137ms/step - accuracy: 0.1765 - loss: 2.8437 - val_accuracy: 0.1027 - val_loss: 3.0291 - learning_rate: 1.2500e-04
# Epoch 22/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1290s 138ms/step - accuracy: 0.1778 - loss: 2.8376 - val_accuracy: 0.0998 - val_loss: 3.0466 - learning_rate: 1.2500e-04
# Epoch 23/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.1792 - loss: 2.8366
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 1291s 138ms/step - accuracy: 0.1792 - loss: 2.8366 - val_accuracy: 0.0980 - val_loss: 3.0552 - learning_rate: 1.2500e-04
# Epoch 1/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 3258s 289ms/step - accuracy: 0.6095 - loss: 2.0364 - val_accuracy: 0.8627 - val_loss: 0.5118 - learning_rate: 0.0010
# Epoch 2/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2720s 290ms/step - accuracy: 0.9313 - loss: 0.2439 - val_accuracy: 0.9252 - val_loss: 0.2607 - learning_rate: 0.0010
# Epoch 3/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2713s 289ms/step - accuracy: 0.9595 - loss: 0.1417 - val_accuracy: 0.9053 - val_loss: 0.3510 - learning_rate: 0.0010
# Epoch 4/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2660s 284ms/step - accuracy: 0.9724 - loss: 0.0949 - val_accuracy: 0.9416 - val_loss: 0.2230 - learning_rate: 0.0010
# Epoch 5/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 4002s 427ms/step - accuracy: 0.9796 - loss: 0.0720 - val_accuracy: 0.9388 - val_loss: 0.2269 - learning_rate: 0.0010
# Epoch 6/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2682s 286ms/step - accuracy: 0.9836 - loss: 0.0568 - val_accuracy: 0.9353 - val_loss: 0.2454 - learning_rate: 0.0010
# Epoch 7/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2698s 288ms/step - accuracy: 0.9867 - loss: 0.0465 - val_accuracy: 0.9485 - val_loss: 0.2067 - learning_rate: 0.0010
# Epoch 8/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2715s 290ms/step - accuracy: 0.9888 - loss: 0.0397 - val_accuracy: 0.9516 - val_loss: 0.1952 - learning_rate: 0.0010
# Epoch 9/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2784s 297ms/step - accuracy: 0.9899 - loss: 0.0348 - val_accuracy: 0.9497 - val_loss: 0.2105 - learning_rate: 0.0010
# Epoch 10/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2700s 288ms/step - accuracy: 0.9912 - loss: 0.0310 - val_accuracy: 0.9550 - val_loss: 0.1879 - learning_rate: 0.0010
# Epoch 11/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 12052s 1s/step - accuracy: 0.9919 - loss: 0.0284 - val_accuracy: 0.9456 - val_loss: 0.2548 - learning_rate: 0.0010
# Epoch 12/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 28462s 3s/step - accuracy: 0.9924 - loss: 0.0274 - val_accuracy: 0.9537 - val_loss: 0.2140 - learning_rate: 0.0010
# Epoch 13/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.9930 - loss: 0.0246
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 7034s 750ms/step - accuracy: 0.9930 - loss: 0.0246 - val_accuracy: 0.9409 - val_loss: 0.2649 - learning_rate: 0.0010
# Epoch 14/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2681s 286ms/step - accuracy: 0.9967 - loss: 0.0115 - val_accuracy: 0.9617 - val_loss: 0.1803 - learning_rate: 5.0000e-04
# Epoch 15/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2687s 287ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 0.9600 - val_loss: 0.1817 - learning_rate: 5.0000e-04
# Epoch 16/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 2695s 287ms/step - accuracy: 0.9981 - loss: 0.0067 - val_accuracy: 0.9642 - val_loss: 0.1801 - learning_rate: 5.0000e-04
# Epoch 17/100
# 9375/9375 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9983 - loss: 0.0063

# %% [markdown]
# ## 3.3.6 Notebook completed
